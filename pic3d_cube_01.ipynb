# %% [markdown]
# <a href="https://colab.research.google.com/github/barreler126/test001/blob/main/pic3d_cube_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
"""接续02，把人像贴在立方体面上"""
from google.colab import files
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from PIL import Image
import numpy as np
import os

current_path = os.getcwd()

print(current_path)
filename = list(files.upload())[0]
print(filename)
# 读取图片
# image_path = r'/Home/imageX.jpg'
# image = Image.open(filename)
Image.open(filename).show()
Image.open(filename)
files.upload()
# 将"图像转换为NumPy数组
image_array = np.array(image)

# 获取图像的尺寸
height, width, _ = image_array.shape
print(height, width)
height = width
print(height, width)

# 创建一个三维图像
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# 将图像的每个像素放置在三维空间中
for i in range(0, height, 3):
    for j in range(0, width, 3):
        color = image_array[i, j]  # 将像素值归一化到[0, 1] color = image_array[i, j] / 255.0
        ax.scatter(i, j, 0, c=color / 255, marker='.')
        ax.scatter(0, j, i, c=color / 255, marker='o')
        ax.scatter(i, 0, j, c=color / 255, marker='o')
        # ax.scatter(i, j, 99, c=color / 255, marker='.')
        # ax.scatter(99, j, i, c=color / 255, marker='o')
        # ax.scatter(i, 99, j, c=color / 255, marker='o')

# 设置坐标轴标签
# ax.set_xlabel('Height')
# ax.set_ylabel('Width')
# ax.set_zlabel('Color')

# 显示图像
plt.show()
# Out:
# /content
#      <input type="file" id="files-4333097b-7ff8-4b77-84e1-bce8fe97ada1" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-4333097b-7ff8-4b77-84e1-bce8fe97ada1">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# ...

# %%
"""接续02，把人像贴在立方体面上"""
# !pip install PIL
from google.colab import files
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from PIL import Image
import numpy as np
# import os

# current_path = os.getcwd()

print(current_path)
filename = 'imageX (2).jpg'

print(filename)
image = Image.open(filename)

files.upload()
# files.list()
image = Image.open(filename).show()
image = Image.open(filename)
# image = Image(filename)

files.upload()
# 将"图像转换为NumPy数组
image_array = np.array(image)

# 获取图像的尺寸
height, width = 100 , 100
print(height, width)
height = width
print(height, width)

# 创建一个三维图像
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# 将图像的每个像素放置在三维空间中
for i in range(0, height, 3):
    for j in range(0, width, 3):
        color = image_array[i, j]  # 将像素值归一化到[0, 1] color = image_array[i, j] / 255.0
        ax.scatter(i, j, 0, c=color / 255, marker='.')
        # ax.scatter(0, j, i, c=color / 255, marker='o')
        # ax.scatter(i, 0, j, c=color / 255, marker='o')
        # ax.scatter(i, j, 99, c=color / 255, marker='.')
        # ax.scatter(99, j, i, c=color / 255, marker='o')
        # ax.scatter(i, 99, j, c=color / 255, marker='o')

# 设置坐标轴标签
# ax.set_xlabel('Height')
# ax.set_ylabel('Width')
# ax.set_zlabel('Color')

# 显示图像
plt.show()
# Out:
# ERROR: Could not find a version that satisfies the requirement PIL (from versions: none)
# ERROR: No matching distribution found for PIL
# /content
# imageX (2).jpg
#      <input type="file" id="files-8b0cf656-4dd3-4a9d-9112-bd842d333e74" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-8b0cf656-4dd3-4a9d-9112-bd842d333e74">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# ...

# %%
import os

# 获取当前工作目录
current_directory = os.getcwd()

print("当前工作目录:", current_directory)
# Out:
# 当前工作目录: /content

# %%
import os

# 获取当前路径
cwd = os.getcwd()

# 获取文件的绝对路径
filename = os.path.join(cwd, 'imageX.jpg')

# 打开文件
with open(filename, 'r') as f:
    content = f.read()

print(content)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-13-4a3c4c1b3f9c> in <cell line: 10>()
#       8
#       9 # 打开文件
# ---> 10 with open(filename, 'r') as f:
#      11     content = f.read()
#      12
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/imageX.jpg'

# %%
from google.colab import files

# 上传图形文件
# files.upload()

# 显示图形文件
from IPython.display import Image

# 获取图形文件的路径
# filename = 'my_image.png'

# 显示图形文件
Image(files.upload())
# Out:
#      <input type="file" id="files-b96cfdb1-c4a5-485a-864f-9bfd01a5fbe7" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b96cfdb1-c4a5-485a-864f-9bfd01a5fbe7">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from google.colab import files

# 上传图形文件
# files.upload()

# 显示图形文件
from IPython.display import Image

# 获取图形文件的路径
filename = 'my_image.png'

# 显示图形文件
Image(files.upload()[:1][0])
# Out:
#      <input type="file" id="files-cf9f0657-56e3-4316-9bed-337dc45c6e11" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-cf9f0657-56e3-4316-9bed-337dc45c6e11">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from google.colab import files

# 上传图形文件
# files.upload()

# 显示图形文件
from IPython.display import Image

# 获取图形文件的路径
# filename = 'my_image.png'

# 显示图形文件
Image(files.upload()[:1][0])
# Out:
#      <input type="file" id="files-718cdd8c-14bf-4076-aae0-271e013655a1" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-718cdd8c-14bf-4076-aae0-271e013655a1">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from google.colab import files

# 上传图形文件
# files.upload()

# 显示图形文件
from IPython.display import Image

# 获取图形文件的路径
# filename = 'my_image.png'

# 将列表转换为可散列的对象
filename = list(files.upload())[0]
print(filename)
# 显示图形文件
Image(filename)
# Out:
#      <input type="file" id="files-d1c397b0-78b7-4998-8a84-39e5705873e8" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d1c397b0-78b7-4998-8a84-39e5705873e8">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import os

# 查看/content目录下的文件
files_in_content = os.listdir('/content/..')
print("内容目录下的文件:", files_in_content)
# Out:
# 内容目录下的文件: ['lib', 'dev', 'srv', 'opt', 'tmp', 'libx32', 'root', 'mnt', 'var', 'boot', 'bin', 'etc', 'lib32', 'home', 'sys', 'lib64', 'proc', 'media', 'run', 'usr', 'sbin', 'content', '.dockerenv', 'tools', 'datalab', 'python-apt', 'NGC-DL-CONTAINER-LICENSE', 'cuda-keyring_1.0-1_all.deb']

# %%
# 需要安装
from google.colab import drive
drive.mount('/content/drive')
# !mv * /content/drive/
# Out:
# ---------------------------------------------------------------------------
# MessageError                              Traceback (most recent call last)
# <ipython-input-69-39f5a80da2f5> in <cell line: 2>()
#       1 from google.colab import drive
# ----> 2 drive.mount('/content/drive')
#       3 get_ipython().system('mv * /content/drive/')
#
# /usr/local/lib/python3.10/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, readonly)
#      98 def mount(mountpoint, force_remount=False, timeout_ms=120000, readonly=False):
#      99   """Mount your Google Drive at the specified mountpoint path."""
# --> 100   return _mount(
#     101       mountpoint,
#     102       force_remount=force_remount,
#
# /usr/local/lib/python3.10/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, ephemeral, readonly)
#     127   )
#     128   if ephemeral:
# --> 129     _message.blocking_request(
# ...
